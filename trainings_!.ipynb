# %%
a = 'Alex'
b = 'Misha'
print ('{} want to play football with {}'.format (a,b) )
print (f"{a} want to play football with {b}")
# Out:
# Alex want to play football with Misha
# Alex want to play football with Misha

# %%
import random
for i in range(3):
    print(random.randint(1, 1000))

for i in range(5):
    random.seed(0)
    print(random.randint(1, 1000))
# Out:
# 395
# 777
# 912
# 865
# 865
# 865
# 865
# 865

# %%
3E-4
# Out:
# 0.0003

# %%
print ('{0:.7f}'.format(1/3))
# Out:
# 0.3333333

# %%
# while circle
while
# Out:
#   Cell In[5], line 2
#     while
#           ^
# SyntaxError: invalid syntax
